# %%
import numpy as np
import pandas as pd

# %%
breast=pd.read_csv('breast cancer (1).csv')
breast.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
breast.shape
breast.duplicated().sum()
breast.isnull().sum()
breast.drop('Unnamed: 32',axis=1,inplace=True)
breast.describe()
breast['diagnosis'] = breast['diagnosis'].map({'M':1,'B':0})
breast.shape
# Out:
# (569, 32)

# %%
x=breast.drop('diagnosis',axis=1)
y=breast['diagnosis']

# %%
x.shape
# Out:
# (569, 31)

# %%
# prompt: split dat in traing set and testing test

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
y_test.shape
# Out:
# (455, 31)
# (114, 31)
# (455,)
# (114,)

# %%
# prompt: do feature scaling

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 3
#       1 # prompt: do feature scaling
# ----> 3 from sklearn.preprocessing import StandardScaler
#       4 scaler = StandardScaler()
#       5 x_train = scaler.fit_transform(x_train)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
x_train
# Out:
# array([[-0.23712699, -1.44075296, -0.43531947, ...,  2.09724217,
#          1.88645014,         nan],
#        [-0.23702031,  1.97409619,  1.73302577, ...,  1.89116053,
#          2.49783848,         nan],
#        [-0.23712907, -1.39998202, -1.24962228, ...,  0.59760192,
#          0.0578942 ,         nan],
#        ...,
#        [-0.17630431,  0.04880192, -0.55500086, ..., -0.70863864,
#         -1.27145475,         nan],
#        [-0.23675669, -0.03896885,  0.10207345, ...,  0.43432185,
#          1.21336207,         nan],
#        [-0.2371006 , -0.54860557,  0.31327591, ..., -0.3345212 ,
#         -0.84628745,         nan]])

# %%
# prompt: train the model

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load the dataset (assuming it's already uploaded to Colab)
breast = pd.read_csv('/content/breast cancer.csv')

# Preprocessing steps (as provided in the original code)
breast.drop('Unnamed: 32', axis=1, inplace=True)
breast['diagnosis'] = breast['diagnosis'].map({'M': 1, 'B': 0})
x = breast.drop('diagnosis', axis=1)
y = breast['diagnosis']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# Initialize and train a Logistic Regression model
model = LogisticRegression()
model.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the Logistic Regression model: {accuracy}")
# Out:
# Accuracy of the Logistic Regression model: 0.9736842105263158

# %%
# prompt: make pridiction system breast cancer 2 line code with minpu and message if hre is  maligen so cancer and bengin is non cancerious make one input variable for inpu

import numpy as np
input_data = np.array([[-0.23711093, -0.4976419 ,  0.61365274, -0.49813131, -0.53102815,
       -0.57694824, -0.17494424, -0.36215622, -0.284859  ,  0.43345165,
        0.17818232, -0.36844966,  0.55310406, -0.31671104, -0.40524636,
        0.04025752, -0.03795529, -0.18043065,  0.16478901, -0.12170969,
        0.23079329, -0.50044002,  0.81940367, -0.46922838, -0.53308833,
       -0.04910117, -0.04160193, -0.14913653,  0.09681787,  0.10617647,
        0.49035329]])
prediction = model.predict(input_data)
print("Prediction:", "Cancer" if prediction[0] == 1 else "Non-cancerous")
# Out:
# Prediction: Non-cancerous

# %%
x_train[10]
# Out:
# array([-0.23711093, -0.4976419 ,  0.61365274, -0.49813131, -0.53102815,
#        -0.57694824, -0.17494424, -0.36215622, -0.284859  ,  0.43345165,
#         0.17818232, -0.36844966,  0.55310406, -0.31671104, -0.40524636,
#         0.04025752, -0.03795529, -0.18043065,  0.16478901, -0.12170969,
#         0.23079329, -0.50044002,  0.81940367, -0.46922838, -0.53308833,
#        -0.04910117, -0.04160193, -0.14913653,  0.09681787,  0.10617647,
#         0.49035329])

# %%
# prompt: pickle file  and in exention in module.pkl only pickel the file import onbly pickle

import pickle
pickle.dump(model,open('module.pkl','wb'))
